# %% [markdown]
# # CVAI SW 02 Übung

# %%
import numpy as np
import matplotlib.pyplot as pl
import cv2 as cv

# %% [markdown]
# ## Aufgabe 1: Unscharfmaskierung mittels Wärmeleitungsgleichung

# %%
img1 = cv.imread ('Images/lenna-blurred.jpg')

# %%
pl.imshow (img1)

# %%
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [20.0..627.5].

# %% [markdown]
# ## Aufgabe 2: Rauschunterdrückung mit Medianfilter

# %%
img2 = cv.imread ('Images/gw-test-pattern-noise.jpg')

# %%
pl.imshow (img2)

# %%
img_median = ...

# %%
img_blurred = ...
